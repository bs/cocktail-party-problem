# %%
import asteroid
asteroid.__version__
# Out:
# '0.3.3'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import re
from pathlib import Path
import librosa

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
p = Path(r'Notebooks/MiniLibriMix').glob('**/*')
FILES = [x for x in p if x.is_file()]

# %%
class DataHelper(object):
    def __init__(self, files=FILES):
        self.files = files
        
    def __len__(self):
        return len(self.files)
        
    def get_file_types(self):
        strings = [str(f) for f in self.files]
        types = set(re.split('\.',s)[-1] for s in strings)
        return types
    
    def train_test_split(self):
        strings = [str(f) for f in self.files]
        train = [s for s in strings if re.search('/train/', s)]
        test = [s for s in strings if re.search('/val/', s)]
        return train, test
    
    def load_csv_tables(self):
        train, test = self.train_test_split()
        
        train_csvs = [t for t in train if re.search('.csv', t)]
        test_csvs = [t for t in test if re.search('.csv', t)]
        
        train_dfs = [pd.read_csv(t).rename(columns={'Unnamed: 0': 'index'}) for t in train_csvs]
        train_names = [re.split('/', re.split('\.', t)[-2])[-1] for t in train_csvs]
        
        test_dfs = [pd.read_csv(t).rename(columns={'Unnamed: 0': 'index'}) for t in test_csvs]
        test_names = [re.split('/', re.split('\.', t)[-2])[-1] for t in train_csvs]
        
        train_dict = dict(zip(train_names, train_dfs))
        test_dict = dict(zip(test_names, test_dfs))
        return train_dict, test_dict

# %%
datahelper = DataHelper()
len(datahelper)
datahelper.get_file_types()
train, test = datahelper.train_test_split()
len(train), len(test)
train_dfs, test_dfs = datahelper.load_csv_tables()

# %%
train_df = train_dfs['mixture_train_mix_clean']

# %%
example_1 = train_df.iloc[0]
example_1
# Out:
# index                                                           70
# mixture_ID                         5400-34479-0005_4973-24515-0007
# mixture_path     MiniLibriMix/train/mix_clean/5400-34479-0005_4...
# source_1_path    MiniLibriMix/train/s1/5400-34479-0005_4973-245...
# source_2_path    MiniLibriMix/train/s2/5400-34479-0005_4973-245...
# length                                                      121920
# Name: 0, dtype: object

# %%
mixture_path = example_1['mixture_path']
src_1_path = example_1['source_1_path']
src_2_path = example_1['source_2_path']

# %%
mixture, sr = librosa.load('Notebooks/'+mixture_path, sr=None)
src_1, _ = librosa.load('Notebooks/'+src_1_path, sr=None)
src_2, _ = librosa.load('Notebooks/'+src_2_path, sr=None)

# %%
def generate_spectrogram(signal, sr=8000, low_lim=0, high_lim=8000//2):
    S = librosa.stft(signal)
    return S

# %%
S_X = np.expand_dims(np.expand_dims(generate_spectrogram(mixture)[:1024, :128], axis=0),axis=0)
S_X.shape
# Out:
# (1, 1, 1024, 128)

# %%
S_Y1 = np.expand_dims(generate_spectrogram(src_1)[:1024, :128], axis=0)
S_Y2 = np.expand_dims(generate_spectrogram(src_2)[:1024, :128], axis=0)
S_Y = np.expand_dims(np.concatenate([S_Y1, S_Y2], axis=0), axis=0)
S_Y.shape
# Out:
# (1, 2, 1024, 128)

# %%
from IPython.display import Audio
Audio(librosa.core.istft(np.squeeze(S_X[0,0,:,:])), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(librosa.core.istft(np.squeeze(S_Y[0,0,:,:])), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(librosa.core.istft(np.squeeze(S_Y[0,1,:,:])), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dir(asteroid.models)
# Out:
# ['ConvTasNet',
#  'DPRNNTasNet',
#  'DPTNet',
#  'DeMask',
#  'LSTMTasNet',
#  'SuDORMRFImprovedNet',
#  'SuDORMRFNet',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'base_models',
#  'conv_tasnet',
#  'demask',
#  'dprnn_tasnet',
#  'dptnet',
#  'get',
#  'lstm_tasnet',
#  'publisher',
#  'register_model',
#  'save_publishable',
#  'sudormrf',
#  'upload_publishable',
#  'zenodo']

# %%
model = asteroid.models.conv_tasnet.ConvTasNet(n_src=2)

# %%
model
# Out:
# ConvTasNet(
#   (encoder): Encoder(
#     (filterbank): FreeFB()
#   )
#   (masker): TDConvNet(
#     (bottleneck): Sequential(
#       (0): GlobLN()
#       (1): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#     )
#     (TCN): ModuleList(
#       (0): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (1): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (2): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(4,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (3): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (4): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(16,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (5): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(32,), dilation=(32,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (6): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(64,), dilation=(64,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (7): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(128,), dilation=(128,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (8): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (9): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (10): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(4,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (11): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (12): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(16,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (13): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(32,), dilation=(32,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (14): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(64,), dilation=(64,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (15): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(128,), dilation=(128,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (16): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (17): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (18): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(4,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (19): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (20): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(16,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (21): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(32,), dilation=(32,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (22): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(64,), dilation=(64,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#       (23): Conv1DBlock(
#         (shared_block): Sequential(
#           (0): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#           (1): PReLU(num_parameters=1)
#           (2): GlobLN()
#           (3): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(128,), dilation=(128,), groups=512)
#           (4): PReLU(num_parameters=1)
#           (5): GlobLN()
#         )
#         (res_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (mask_net): Sequential(
#       (0): PReLU(num_parameters=1)
#       (1): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     )
#     (output_act): Sigmoid()
#   )
#   (decoder): Decoder(
#     (filterbank): FreeFB()
#   )
#   (enc_activation): ReLU()
# )

# %%
inpt = mixture
outpt = model(torch.Tensor(mixture)).detach().numpy()

# %%
Audio(inpt, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(outpt[0], rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from asteroid.losses import PITLossWrapper
from asteroid.losses import pairwise_mse, singlesrc_mse, multisrc_mse

model = asteroid.models.conv_tasnet.ConvTasNet(n_src=2).to('cuda')
X = torch.Tensor(np.expand_dims(np.expand_dims(mixture, axis=0),axis=0)).to('cuda')
Y = torch.Tensor(np.expand_dims(np.vstack([src_1, src_2]),axis=0)).to('cuda')
loss_func = asteroid.losses.PITLossWrapper(pairwise_mse, pit_from='pw_mtx')

import torch.optim as optim

criterion = loss_func
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
losses = []
for epoch in range(200):

    X_inputs, Y_outputs = X, Y

    optimizer.zero_grad()

    outputs = model(X_inputs)
    loss = criterion(outputs, Y_outputs)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())

    print(f'Epoch: {epoch} >>>>>>>>>>>>>> Loss: {loss.item()}')
# Out:
# Epoch: 0 >>>>>>>>>>>>>> Loss: 0.0005621500895358622
# Epoch: 1 >>>>>>>>>>>>>> Loss: 0.0005621499149128795
# Epoch: 2 >>>>>>>>>>>>>> Loss: 0.000562149565666914
# Epoch: 3 >>>>>>>>>>>>>> Loss: 0.0005621489835903049
# Epoch: 4 >>>>>>>>>>>>>> Loss: 0.0005621482850983739
# Epoch: 5 >>>>>>>>>>>>>> Loss: 0.0005621474701911211
# Epoch: 6 >>>>>>>>>>>>>> Loss: 0.0005621465388685465
# Epoch: 7 >>>>>>>>>>>>>> Loss: 0.00056214549113065
# Epoch: 8 >>>>>>>>>>>>>> Loss: 0.0005621443269774318
# Epoch: 9 >>>>>>>>>>>>>> Loss: 0.0005621430464088917
# Epoch: 10 >>>>>>>>>>>>>> Loss: 0.0005621417658403516
# Epoch: 11 >>>>>>>>>>>>>> Loss: 0.0005621403688564897
# Epoch: 12 >>>>>>>>>>>>>> Loss: 0.0005621389136649668
# Epoch: 13 >>>>>>>>>>>>>> Loss: 0.0005621373420581222
# Epoch: 177 >>>>>>>>>>>>>> Loss: 0.0005618083523586392
# Epoch: 178 >>>>>>>>>>>>>> Loss: 0.0005618063150905073
# Epoch: 179 >>>>>>>>>>>>>> Loss: 0.0005618042778223753
# Epoch: 180 >>>>>>>>>>>>>> Loss: 0.0005618022405542433
# Epoch: 181 >>>>>>>>>>>>>> Loss: 0.0005618002614937723
# Epoch: 182 >>>>>>>>>>>>>> Loss: 0.0005617981660179794
# Epoch: 183 >>>>>>>>>>>>>> Loss: 0.0005617961287498474
# Epoch: 184 >>>>>>>>>>>>>> Loss: 0.0005617941496893764
# Epoch: 185 >>>>>>>>>>>>>> Loss: 0.0005617920542135835
# Epoch: 186 >>>>>>>>>>>>>> Loss: 0.0005617900751531124
# Epoch: 187 >>>>>>>>>>>>>> Loss: 0.0005617880378849804
# Epoch: 188 >>>>>>>>>>>>>> Loss: 0.0005617860006168485
# Epoch: 189 >>>>>>>>>>>>>> Loss: 0.0005617839633487165
# Epoch: 190 >>>>>>>>>>>>>> Loss: 0.0005617819260805845
# Epoch: 191 >>>>>>>>>>>>>> Loss: 0.0005617798888124526
# Epoch: 192 >>>>>>>>>>>>>> Loss: 0.0005617778515443206
# Epoch: 193 >>>>>>>>>>>>>> Loss: 0.0005617757560685277
# Epoch: 194 >>>>>>>>>>>>>> Loss: 0.0005617737770080566
# Epoch: 195 >>>>>>>>>>>>>> Loss: 0.0005617717979475856
# Epoch: 196 >>>>>>>>>>>>>> Loss: 0.0005617697024717927
# Epoch: 197 >>>>>>>>>>>>>> Loss: 0.0005617676652036607
# Epoch: 198 >>>>>>>>>>>>>> Loss: 0.0005617656279355288
# Epoch: 199 >>>>>>>>>>>>>> Loss: 0.0005617635324597359

# %%
X.shape
# Out:
# torch.Size([1, 1, 121920])

# %%
Y.shape
# Out:
# torch.Size([1, 2, 121920])

# %%
with torch.no_grad():
    out = model(X)

# %%
out1 = out.cpu().numpy()[0,0,:]
out2 = out.cpu().numpy()[0,1,:]

# %%
Audio(out1, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(out2, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(Y[0,0,:].cpu().numpy(), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from torch.optim import Adam
from torch.utils.data import DataLoader
import pytorch_lightning as pl

from asteroid.data import LibriMix
from asteroid.engine.system import System
from asteroid.losses import PITLossWrapper, pairwise_neg_sisdr
from asteroid import ConvTasNet

train_set, val_set = LibriMix.mini_from_download(task='sep_clean')
train_loader = DataLoader(train_set, batch_size=4, drop_last=True)
val_loader = DataLoader(val_set, batch_size=4, drop_last=True)

# Define model and optimizer (one repeat to be faster)
model = ConvTasNet(n_src=2, n_repeats=1)
optimizer = Adam(model.parameters(), lr=1e-3)
# Define Loss function.
loss_func = PITLossWrapper(pairwise_neg_sisdr, pit_from='pw_mtx')
# Define System
system = System(model=model, loss_func=loss_func, optimizer=optimizer,
                train_loader=train_loader, val_loader=val_loader)
# Define lightning trainer, and train
trainer = pl.Trainer(min_epochs=10)
trainer.fit(system)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=640547371.0), HTML(value='')))
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name      | Type           | Params
# ---------------------------------------------
# 0 | model     | ConvTasNet     | 1 M
# 1 | loss_func | PITLossWrapper | 0
# Drop 0 utterances from 800 (shorter than 3 seconds)
# Drop 0 utterances from 200 (shorter than 3 seconds)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# /opt/conda/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   warnings.warn(*args, **kwargs)
# Saving latest checkpoint..
# 1

# %%
X0, Y0 = next(iter(train_loader))

# %%
X0.size()
# Out:
# torch.Size([4, 24000])

# %%
Y0.size()
# Out:
# torch.Size([4, 2, 24000])

# %%
Audio(X0[0].numpy(), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(Y0[0,0,:].numpy(), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(Y0[0,1,:].numpy(), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
model(X0).size()
# Out:
# torch.Size([4, 2, 24000])

# %%
Audio(model(X0).detach().cpu().numpy()[0,0,:], rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ls
# Out:
# epoch=0.ckpt

# %%
path = Path('lightning_logs/version_0/checkpoints/epoch=0.ckpt')

# %%
path
# Out:
# PosixPath('lightning_logs/version_0/checkpoints/epoch=0.ckpt')

# %%
System.load_from_checkpoint('lightning_logs/version_0/checkpoints/epoch=0.ckpt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-85-f7fb920e2941> in <module>
# ----> 1 System.load_from_checkpoint('lightning_logs/version_0/checkpoints/epoch=0.ckpt')
#
# /opt/conda/lib/python3.7/site-packages/pytorch_lightning/core/saving.py in load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, *args, **kwargs)
#     129             checkpoint = pl_load(checkpoint_path, map_location=map_location)
#     130         else:
# --> 131             checkpoint = pl_load(checkpoint_path, map_location=lambda storage, loc: storage)
#     132
#     133         if hparams_file is not None:
#
# /opt/conda/lib/python3.7/site-packages/pytorch_lightning/utilities/cloud_io.py in load(path_or_url, map_location)
#      41 def load(path_or_url: str, map_location=None):
#      42     if urlparse(path_or_url).scheme == '' or Path(path_or_url).drive:  # no scheme or with a drive letter
# ---> 43         return torch.load(path_or_url, map_location=map_location)
#      44     return torch.hub.load_state_dict_from_url(path_or_url, map_location=map_location)
#      45
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     569         pickle_load_args['encoding'] = 'utf-8'
#     570
# --> 571     with _open_file_like(f, 'rb') as opened_file:
#     572         if _is_zipfile(opened_file):
#     573             # The zipfile reader is going to advance the current file position.
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     227 def _open_file_like(name_or_buffer, mode):
#     228     if _is_path(name_or_buffer):
# --> 229         return _open_file(name_or_buffer, mode)
#     230     else:
#     231         if 'w' in mode:
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     208 class _open_file(_opener):
#     209     def __init__(self, name, mode):
# --> 210         super(_open_file, self).__init__(open(name, mode))
#     211
#     212     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lightning_logs/version_0/checkpoints/epoch=0.ckpt'

# %%
Path
# Out:
# pathlib.Path

# %%
pwd
# Out:
# '/home/peterbermant/Workspace/Cocktail-Party-Problem/Human-Speech-and-Music/Asteroid-Experimentation'

# %%
cd lightning_logs
# Out:
# /home/peterbermant/Workspace/Cocktail-Party-Problem/Human-Speech-and-Music/Asteroid-Experimentation/lightning_logs

# %%
ls
# Out:
# version_0/

# %%
cd version_0
# Out:
# /home/peterbermant/Workspace/Cocktail-Party-Problem/Human-Speech-and-Music/Asteroid-Experimentation/lightning_logs/version_0

# %%
ls
# Out:
# checkpoints/                                                   hparams.yaml
# events.out.tfevents.1600706014.peter-deep-ml-workspace.2774.0

# %%
cd checkpoints
# Out:
# /home/peterbermant/Workspace/Cocktail-Party-Problem/Human-Speech-and-Music/Asteroid-Experimentation/lightning_logs/version_0/checkpoints

# %%
ls
# Out:
# epoch=0.ckpt

# %%
.shape
# Out:
#   File "<ipython-input-26-abefa8d9bb1a>", line 1
#     .shape
#     ^
# SyntaxError: invalid syntax
